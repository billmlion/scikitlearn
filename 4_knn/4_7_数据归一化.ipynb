# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
# ### 数据归一化：
# >最值归一化
# * 适用于分布有明显边界的情况；
#
# >均值方差归一化
# * 数据分布没有明显边界；可能存在极端数据值

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
# ### 最值归一化 Normalization

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.randint(0, 100, size=100)

# %%
x
# Out:
# array([46, 78, 59, 86, 10, 81, 88, 32, 46, 10, 32, 31, 87, 31, 13, 75, 66,
#        28, 24, 46, 28, 86, 18, 93, 68, 66, 59, 45, 52, 32,  2, 25,  4, 33,
#        76, 70, 80, 43, 10, 53, 21, 70, 33,  4, 88, 54, 87, 17, 86, 90, 36,
#        76, 93, 49, 36, 96, 15, 99, 87, 58, 31, 90, 85, 60, 69,  8, 32, 69,
#        69, 56, 94, 13, 88, 60, 43, 11, 68, 96, 79, 24, 42, 68, 54, 58, 28,
#        76, 18, 78, 81, 73, 24, 96, 18, 96, 92, 16, 20, 68, 50, 91])

# %%
(x - np.min(x))/(np.max(x) - np.min(x))
# Out:
# array([0.45360825, 0.78350515, 0.58762887, 0.86597938, 0.08247423,
#        0.81443299, 0.88659794, 0.30927835, 0.45360825, 0.08247423,
#        0.30927835, 0.29896907, 0.87628866, 0.29896907, 0.11340206,
#        0.75257732, 0.65979381, 0.26804124, 0.22680412, 0.45360825,
#        0.26804124, 0.86597938, 0.16494845, 0.93814433, 0.68041237,
#        0.65979381, 0.58762887, 0.44329897, 0.51546392, 0.30927835,
#        0.        , 0.2371134 , 0.02061856, 0.31958763, 0.7628866 ,
#        0.70103093, 0.80412371, 0.42268041, 0.08247423, 0.5257732 ,
#        0.19587629, 0.70103093, 0.31958763, 0.02061856, 0.88659794,
#        0.53608247, 0.87628866, 0.15463918, 0.86597938, 0.90721649,
#        0.35051546, 0.7628866 , 0.93814433, 0.48453608, 0.35051546,
#        0.96907216, 0.13402062, 1.        , 0.87628866, 0.57731959,
#        0.29896907, 0.90721649, 0.8556701 , 0.59793814, 0.69072165,
#        0.06185567, 0.30927835, 0.69072165, 0.69072165, 0.55670103,
#        0.94845361, 0.11340206, 0.88659794, 0.59793814, 0.42268041,
#        0.09278351, 0.68041237, 0.96907216, 0.79381443, 0.22680412,
#        0.41237113, 0.68041237, 0.53608247, 0.57731959, 0.26804124,
#        0.7628866 , 0.16494845, 0.78350515, 0.81443299, 0.73195876,
#        0.22680412, 0.96907216, 0.16494845, 0.96907216, 0.92783505,
#        0.1443299 , 0.18556701, 0.68041237, 0.49484536, 0.91752577])

# %%
X = np.random.randint(0, 100, (50, 2))

# %%
X[:10,:]
# Out:
# array([[82, 48],
#        [ 1, 39],
#        [27,  1],
#        [27, 85],
#        [22, 96],
#        [ 9, 55],
#        [38, 19],
#        [22, 14],
#        [ 0, 58],
#        [72, 22]])

# %%
X = np.array(X, dtype=float)

# %%
X[:10,:]
# Out:
# array([[82., 48.],
#        [ 1., 39.],
#        [27.,  1.],
#        [27., 85.],
#        [22., 96.],
#        [ 9., 55.],
#        [38., 19.],
#        [22., 14.],
#        [ 0., 58.],
#        [72., 22.]])

# %%
X[:,0] = (X[:,0] - np.min(X[:, 0]))/(np.max(X[:,0]) - np.min(X[:, 0]))

# %%
X[:,1] = (X[:,1] - np.min(X[:, 1]))/(np.max(X[:,1]) - np.min(X[:, 1]))

# %%
X[:10, :]
# Out:
# array([[0.88172043, 0.48979592],
#        [0.01075269, 0.39795918],
#        [0.29032258, 0.01020408],
#        [0.29032258, 0.86734694],
#        [0.23655914, 0.97959184],
#        [0.09677419, 0.56122449],
#        [0.40860215, 0.19387755],
#        [0.23655914, 0.14285714],
#        [0.        , 0.59183673],
#        [0.77419355, 0.2244898 ]])

# %%
plt.scatter(X[:,0], X[:,1])
plt.show()

# %% [markdown]
# ### 均值方差归一化Standardization

# %%
X2 = np.random.randint(0, 100, (50, 2))

# %%
X2 = np.array(X2, dtype=float)

# %%
X2[:10,]
# Out:
# array([[30., 86.],
#        [91., 58.],
#        [89., 13.],
#        [87., 15.],
#        [82., 70.],
#        [12., 48.],
#        [46., 35.],
#        [71., 44.],
#        [27., 90.],
#        [59., 88.]])

# %%
np.mean(X2[:, 0])
# Out:
# 50.5

# %%
np.mean(X2[:, 1])
# Out:
# 55.4

# %%
np.std(X2[:,0])
# Out:
# 29.05666876983664

# %%
np.std(X2[:,1])
# Out:
# 29.68972886369965

# %%
X2[:,0] = (X2[:,0] - np.mean(X2[:, 0]))/np.std(X2[:,0])

# %%
X2[:,1] = (X2[:,1] - np.mean(X2[:, 1]))/np.std(X2[:,1])

# %%
plt.scatter(X2[:,0], X2[:,1])
plt.show()
