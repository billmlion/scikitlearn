# %% [markdown]
# # 精准率和召回率
# > 精准率：预测值为“1”的正确比例
#
# > 召回率：真实值为“1”的正确比例

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
# # 有偏的数据中准确率在评估算法上无意义
