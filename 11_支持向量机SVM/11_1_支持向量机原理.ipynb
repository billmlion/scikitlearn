# %% [markdown]
# ### SVM 可解决分类和回归问题
# > 其特点有考虑未知点泛化
#
# > 利用支撑向量来确定决策边界
#
#
# * Hard Margin SVM 解决的是线性可分问题，所有点都明确划分清楚
# * Soft Margin SVM 解决的是非线性可分问题，允许少量点未划分正确

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
