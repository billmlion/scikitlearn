# %% [markdown]
# ###  使用向量化实现SimpleLinearRegression
#
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

m = 1000000
big_x = np.random.random(size=m)
big_y = big_x * 2.0 + 3.0 + np.random.normal(size=m)

# %run SimpleLinearRegression.py  #使用向量化
# %run SimpleLinearRegression0.py #使用循环

# %%
reg0 = SimpleLinearRegression0()
# %timeit reg0.fit(big_x, big_y)
# Out:
# 1.01 s ± 26 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
reg1 = SimpleLinearRegression()
# %timeit reg1.fit(big_x, big_y)
# Out:
# 20.3 ms ± 2.71 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
reg0.a_
# Out:
# 2.0014308493035817

# %%
reg0.b_
# Out:
# 2.9997252116364392

# %%
reg1.a_
# Out:
# 2.004027535591079

# %%
reg1.b_
# Out:
# 2.997264449958045
