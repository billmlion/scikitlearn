# %% [markdown]
# ### 梯度下降法
#
# * 不是机器学习算法
# * <b>是一种基于搜索的最优化方法</b>（通过导数求极值方式）
# * 作用：最小化一个损失函数
# * 梯度上升法：最大化一个效用函数
#
# > 并不是所有函数都有极值，可取边界值作为最值
#
#
# #### [参考文章]
#
# https://www.cnblogs.com/pinard/p/5970503.html

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
#
#
#
# # <font color=#A52A2A>theta为未知值，需要求解的值，y和x为样本已知值</font>
